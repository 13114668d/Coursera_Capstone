# %%
import pandas as pd
import numpy as np
import os
print(os.getcwd())
# Out:
# /resources/labs/DP0701EN

# %%
df = pd.read_csv('Processed Data')
df.sort_values(by = ['Postal'])
# Out:
#          Borough Postal                                       Neighborhood
# 75   Scarborough    M1B                                     Rouge, Malvern
# 76   Scarborough    M1C             Highland Creek, Rouge Hill, Port Union
# 77   Scarborough    M1E                  Guildwood, Morningside, West Hill
# 78   Scarborough    M1G                                             Woburn
# 79   Scarborough    M1H                                          Cedarbrae
# ..           ...    ...                                                ...
# 102         York    M9N                                             Weston
# 45     Etobicoke    M9P                                          Westmount
# 46     Etobicoke    M9R  Kingsview Village, Martin Grove Gardens, Richv...
# 47     Etobicoke    M9V  Albion Gardens, Beaumond Heights, Humbergate, ...
# 48     Etobicoke    M9W                                          Northwest
#
# [103 rows x 3 columns]

# %%
import geocoder # import geocoder

# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-15d80b1bb123> in <module>
# ----> 1 import geocoder # import geocoder
#       2
#       3 # initialize your variable to None
#       4 lat_lng_coords = None
#       5
#
# ModuleNotFoundError: No module named 'geocoder'

# %%
gd = pd.read_csv('Geospatial_Coordinates.csv')
gd
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %%
df['Latitude'] = gd['Latitude']
df['Longitude'] = gd['Longitude']
df
# Out:
#              Borough Postal                                    Neighborhood  \
# 0    Central Toronto    M4N                                   Lawrence Park
# 1    Central Toronto    M4P                                Davisville North
# 2    Central Toronto    M4R                              North Toronto West
# 3    Central Toronto    M4S                                      Davisville
# 4    Central Toronto    M4T                     Moore Park, Summerhill East
# ..               ...    ...                                             ...
# 98              York    M6C                              Humewood-Cedarvale
# 99              York    M6E                             Caledonia-Fairbanks
# 100             York    M6M  Del Ray, Keelesdale, Mount Dennis, Silverthorn
# 101             York    M6N                   The Junction North, Runnymede
# 102             York    M9N                                          Weston
#
#       Latitude  Longitude
# 0    43.806686 -79.194353
# 1    43.784535 -79.160497
# 2    43.763573 -79.188711
# 3    43.770992 -79.216917
# 4    43.773136 -79.239476
# ..         ...        ...
# 98   43.706876 -79.518188
# 99   43.696319 -79.532242
# 100  43.688905 -79.554724
# 101  43.739416 -79.588437
# 102  43.706748 -79.594054
#
# [103 rows x 5 columns]

# %%
df.to_csv('Data with Coordinate', index = False)
